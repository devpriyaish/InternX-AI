# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_core.documents import Document

# %%
doc1 = Document(
    page_content="Apples are crisp, sweet fruits that grow on apple trees.",
    metadata={"category": "Fruits", "name": "Apple"}
)

doc2 = Document(
    page_content="Carrots are orange root vegetables that are rich in vitamin A.",
    metadata={"category": "Vegetables", "name": "Carrot"}
)

doc3 = Document(
    page_content="Potatoes are starchy vegetables commonly used in fries and chips.",
    metadata={"category": "Vegetables", "name": "Potato"}
)

doc4 = Document(
    page_content="Sunflowers are tall flowers with bright yellow petals that follow sunlight.",
    metadata={"category": "Flowers", "name": "Sunflower"}
)

doc5 = Document(
    page_content="Cats are small carnivorous mammals known for their independence.",
    metadata={"category": "Animals", "name": "Cat"}
)

doc6 = Document(
    page_content="Bananas are long, curved fruits that are rich in potassium.",
    metadata={"category": "Fruits", "name": "Banana"}
)

doc7 = Document(
    page_content="Spinach is a leafy green vegetable packed with iron and nutrients.",
    metadata={"category": "Vegetables", "name": "Spinach"}
)

doc8 = Document(
    page_content="Roses are popular flowers known for their beauty and fragrance.",
    metadata={"category": "Flowers", "name": "Rose"}
)

doc9 = Document(
    page_content="Lotus flowers grow in water and are considered sacred in many cultures.",
    metadata={"category": "Flowers", "name": "Lotus"}
)

doc10 = Document(
    page_content="Dogs are loyal domestic animals often kept as pets.",
    metadata={"category": "Animals", "name": "Dog"}
)

# %%
docs = [doc1, doc2, doc3, doc4, doc5, doc6, doc7, doc8, doc9, doc10]

# %%
vector_store.get(include=["metadatas", "documents", "embeddings"])
# Out:
# {'ids': ['27c5db7a-5615-4997-8633-72e903f4b938',
#   '9837d071-1e13-4503-8019-6957aeb881d6',
#   'a8116e01-f16a-4944-ab37-21562c3f5467',
#   '3b26027b-7c8f-4c48-930b-deb4466ea94d',
#   'bc17c955-8903-4d6a-af74-96e5eb152407',
#   '2d710c1f-6b25-4c14-a4b5-b12c1f3480f7',
#   '78b84bb8-6930-4898-b727-2ca050294c0f',
#   '23a7e1bc-a634-4a4e-8de7-9a9e58f78240',
#   '0c96d919-1341-4a71-a09a-343af782a23e',
#   '2bcda2fa-afb8-4493-bdf7-3016187712d5'],
#  'embeddings': array([[ 0.02263863, -0.02438296,  0.00949342, ..., -0.00136786,
#          -0.01402993, -0.00558123],
#         [ 0.02179339, -0.02471629, -0.00015488, ..., -0.00302839,
#          -0.01725616,  0.00996723],
#         [ 0.03335482, -0.00802068,  0.00693302, ...,  0.01693183,
#          -0.01844565, -0.00389267],
#         ...,
#         [-0.00181828, -0.00855663, -0.00842022, ..., -0.0081288 ,
#           0.01272334, -0.00577883],
#         [ 0.00223474, -0.0115056 ,  0.00320829, ..., -0.00945735,
#          -0.00933092, -0.00130228],
#         [ 0.00493594, -0.00299523, -0.01597033, ..., -0.00737532,
#           0.00679089,  0.00360508]], shape=(10, 1536)),
#  'documents': ['Apples are crisp, sweet fruits that grow on apple trees.',
#   'Carrots are orange root vegetables that are rich in vitamin A.',
#   'Potatoes are starchy vegetables commonly used in fries and chips.',
#   'Sunflowers are tall flowers with bright yellow petals that follow sunlight.',
#   'Cats are small carnivorous mammals known for their independence.',
#   'Bananas are long, curved fruits that are rich in potassium.',
#   'Spinach is a leafy green vegetable packed with iron and nutrients.',
#   'Roses are popular flowers known for their beauty and fragrance.',
#   'Lotus flowers grow in water and are considered sacred in many cultures.',
#   'Dogs are loyal domestic animals often kept as pets.'],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'embeddings'],
#  'data': None,
#  'metadatas': [{'category': 'Fruits', 'name': 'Apple'},
#   {'name': 'Carrot', 'category': 'Vegetables'},
#   {'category': 'Vegetables', 'name': 'Potato'},
#   {'name': 'Sunflower', 'category': 'Flowers'},
#   {'category': 'Animals', 'name': 'Cat'},
#   {'name': 'Banana', 'category': 'Fruits'},
#   {'name': 'Spinach', 'category': 'Vegetables'},
#   {'name': 'Rose', 'category': 'Flowers'},
#   {'name': 'Lotus', 'category': 'Flowers'},
#   {'category': 'Animals', 'name': 'Dog'}]}

# %%
vector_store.similarity_search(
    query="What are some examples of fruits?",
    k=3
)
# Out:
# [Document(id='27c5db7a-5615-4997-8633-72e903f4b938', metadata={'category': 'Fruits', 'name': 'Apple'}, page_content='Apples are crisp, sweet fruits that grow on apple trees.'),
#  Document(id='2d710c1f-6b25-4c14-a4b5-b12c1f3480f7', metadata={'name': 'Banana', 'category': 'Fruits'}, page_content='Bananas are long, curved fruits that are rich in potassium.'),
#  Document(id='9837d071-1e13-4503-8019-6957aeb881d6', metadata={'name': 'Carrot', 'category': 'Vegetables'}, page_content='Carrots are orange root vegetables that are rich in vitamin A.')]

# %%
vector_store.similarity_search(
    query="Things that can be used for beautification of home?",
    k=3
)
# Out:
# [Document(id='23a7e1bc-a634-4a4e-8de7-9a9e58f78240', metadata={'category': 'Flowers', 'name': 'Rose'}, page_content='Roses are popular flowers known for their beauty and fragrance.'),
#  Document(id='3b26027b-7c8f-4c48-930b-deb4466ea94d', metadata={'category': 'Flowers', 'name': 'Sunflower'}, page_content='Sunflowers are tall flowers with bright yellow petals that follow sunlight.'),
#  Document(id='27c5db7a-5615-4997-8633-72e903f4b938', metadata={'category': 'Fruits', 'name': 'Apple'}, page_content='Apples are crisp, sweet fruits that grow on apple trees.')]

# %%
# meta-filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"category": "Flowers"}
)
# Out:
# [(Document(id='3b26027b-7c8f-4c48-930b-deb4466ea94d', metadata={'category': 'Flowers', 'name': 'Sunflower'}, page_content='Sunflowers are tall flowers with bright yellow petals that follow sunlight.'),
#   0.5688559412956238),
#  (Document(id='23a7e1bc-a634-4a4e-8de7-9a9e58f78240', metadata={'name': 'Rose', 'category': 'Flowers'}, page_content='Roses are popular flowers known for their beauty and fragrance.'),
#   0.6048964262008667),
#  (Document(id='0c96d919-1341-4a71-a09a-343af782a23e', metadata={'name': 'Lotus', 'category': 'Flowers'}, page_content='Lotus flowers grow in water and are considered sacred in many cultures.'),
#   0.6125329732894897)]

# %%
  # meta-filtering
vector_store.similarity_search_with_score(
    query="Which are the flowers that are used on valentine's day?",
    filter={"category": "Flowers"}
)
# Out:
# [(Document(id='23a7e1bc-a634-4a4e-8de7-9a9e58f78240', metadata={'name': 'Rose', 'category': 'Flowers'}, page_content='Roses are popular flowers known for their beauty and fragrance.'),
#   0.30068522691726685),
#  (Document(id='3b26027b-7c8f-4c48-930b-deb4466ea94d', metadata={'name': 'Sunflower', 'category': 'Flowers'}, page_content='Sunflowers are tall flowers with bright yellow petals that follow sunlight.'),
#   0.39547133445739746),
#  (Document(id='0c96d919-1341-4a71-a09a-343af782a23e', metadata={'name': 'Lotus', 'category': 'Flowers'}, page_content='Lotus flowers grow in water and are considered sacred in many cultures.'),
#   0.39956170320510864)]

# %%
vector_store._similarity_search_with_relevance_scores(
    query="Which are the flowers that are used on valentine's day?",
    filter={"category": "Flowers"}
)
# Out:
# [(Document(id='23a7e1bc-a634-4a4e-8de7-9a9e58f78240', metadata={'name': 'Rose', 'category': 'Flowers'}, page_content='Roses are popular flowers known for their beauty and fragrance.'),
#   0.7874590063435649),
#  (Document(id='3b26027b-7c8f-4c48-930b-deb4466ea94d', metadata={'category': 'Flowers', 'name': 'Sunflower'}, page_content='Sunflowers are tall flowers with bright yellow petals that follow sunlight.'),
#   0.7204362238311467),
#  (Document(id='0c96d919-1341-4a71-a09a-343af782a23e', metadata={'category': 'Flowers', 'name': 'Lotus'}, page_content='Lotus flowers grow in water and are considered sacred in many cultures.'),
#   0.7174983145354221)]

# %%
updated_doc_of_sunflower = Document(
    page_content="Sunflowers are large flowering plants with vibrant yellow petals that often turn toward the sun during the day.",
    metadata={"category": "Flowers", "name": "Sunflower"}
)

vector_store.update_document(
    document_id="3b26027b-7c8f-4c48-930b-deb4466ea94d",
    document=updated_doc_of_sunflower
)

# %%
vector_store._similarity_search_with_relevance_scores(
    query="Which are the flowers that are used on valentine's day?",
    filter={"category": "Flowers"}
)
# Out:
# [(Document(id='23a7e1bc-a634-4a4e-8de7-9a9e58f78240', metadata={'name': 'Rose', 'category': 'Flowers'}, page_content='Roses are popular flowers known for their beauty and fragrance.'),
#   0.7873834370441848),
#  (Document(id='3b26027b-7c8f-4c48-930b-deb4466ea94d', metadata={'category': 'Flowers', 'name': 'Sunflower'}, page_content='Sunflowers are large flowering plants with vibrant yellow petals that often turn toward the sun during the day.'),
#   0.71790551631231),
#  (Document(id='0c96d919-1341-4a71-a09a-343af782a23e', metadata={'name': 'Lotus', 'category': 'Flowers'}, page_content='Lotus flowers grow in water and are considered sacred in many cultures.'),
#   0.717467210161221)]

# %%
vector_store.delete(ids=["3b26027b-7c8f-4c48-930b-deb4466ea94d"])

# %%
vector_store._similarity_search_with_relevance_scores(
    query="Which are the flowers that are used on valentine's day?",
    filter={"category": "Flowers"}
)
# Out:
# [(Document(id='23a7e1bc-a634-4a4e-8de7-9a9e58f78240', metadata={'name': 'Rose', 'category': 'Flowers'}, page_content='Roses are popular flowers known for their beauty and fragrance.'),
#   0.7873834370441848),
#  (Document(id='0c96d919-1341-4a71-a09a-343af782a23e', metadata={'name': 'Lotus', 'category': 'Flowers'}, page_content='Lotus flowers grow in water and are considered sacred in many cultures.'),
#   0.717467210161221)]

# %%
# Out:
# [Document(metadata={'category': 'Fruits', 'name': 'Apple'}, page_content='Apples are crisp, sweet fruits that grow on apple trees.'),
#  Document(metadata={'category': 'Vegetables', 'name': 'Carrot'}, page_content='Carrots are orange root vegetables that are rich in vitamin A.'),
#  Document(metadata={'category': 'Vegetables', 'name': 'Potato'}, page_content='Potatoes are starchy vegetables commonly used in fries and chips.'),
#  Document(metadata={'category': 'Flowers', 'name': 'Sunflower'}, page_content='Sunflowers are tall flowers with bright yellow petals that follow sunlight.'),
#  Document(metadata={'category': 'Animals', 'name': 'Cat'}, page_content='Cats are small carnivorous mammals known for their independence.'),
#  Document(metadata={'category': 'Fruits', 'name': 'Banana'}, page_content='Bananas are long, curved fruits that are rich in potassium.'),
#  Document(metadata={'category': 'Vegetables', 'name': 'Spinach'}, page_content='Spinach is a leafy green vegetable packed with iron and nutrients.'),
#  Document(metadata={'category': 'Flowers', 'name': 'Rose'}, page_content='Roses are popular flowers known for their beauty and fragrance.'),
#  Document(metadata={'category': 'Flowers', 'name': 'Lotus'}, page_content='Lotus flowers grow in water and are considered sacred in many cultures.'),
#  Document(metadata={'category': 'Animals', 'name': 'Dog'}, page_content='Dogs are loyal domestic animals often kept as pets.')]

# %%
vector_store.get(include=["metadatas", "documents", "embeddings"])
# Out:
# {'ids': ['27c5db7a-5615-4997-8633-72e903f4b938',
#   '9837d071-1e13-4503-8019-6957aeb881d6',
#   'a8116e01-f16a-4944-ab37-21562c3f5467',
#   'bc17c955-8903-4d6a-af74-96e5eb152407',
#   '2d710c1f-6b25-4c14-a4b5-b12c1f3480f7',
#   '78b84bb8-6930-4898-b727-2ca050294c0f',
#   '23a7e1bc-a634-4a4e-8de7-9a9e58f78240',
#   '0c96d919-1341-4a71-a09a-343af782a23e',
#   '2bcda2fa-afb8-4493-bdf7-3016187712d5'],
#  'embeddings': array([[ 0.02263863, -0.02438296,  0.00949342, ..., -0.00136786,
#          -0.01402993, -0.00558123],
#         [ 0.02179339, -0.02471629, -0.00015488, ..., -0.00302839,
#          -0.01725616,  0.00996723],
#         [ 0.03335482, -0.00802068,  0.00693302, ...,  0.01693183,
#          -0.01844565, -0.00389267],
#         ...,
#         [-0.00181828, -0.00855663, -0.00842022, ..., -0.0081288 ,
#           0.01272334, -0.00577883],
#         [ 0.00223474, -0.0115056 ,  0.00320829, ..., -0.00945735,
#          -0.00933092, -0.00130228],
#         [ 0.00493594, -0.00299523, -0.01597033, ..., -0.00737532,
#           0.00679089,  0.00360508]], shape=(9, 1536)),
#  'documents': ['Apples are crisp, sweet fruits that grow on apple trees.',
#   'Carrots are orange root vegetables that are rich in vitamin A.',
#   'Potatoes are starchy vegetables commonly used in fries and chips.',
#   'Cats are small carnivorous mammals known for their independence.',
#   'Bananas are long, curved fruits that are rich in potassium.',
#   'Spinach is a leafy green vegetable packed with iron and nutrients.',
#   'Roses are popular flowers known for their beauty and fragrance.',
#   'Lotus flowers grow in water and are considered sacred in many cultures.',
#   'Dogs are loyal domestic animals often kept as pets.'],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'embeddings'],
#  'data': None,
#  'metadatas': [{'category': 'Fruits', 'name': 'Apple'},
#   {'category': 'Vegetables', 'name': 'Carrot'},
#   {'name': 'Potato', 'category': 'Vegetables'},
#   {'category': 'Animals', 'name': 'Cat'},
#   {'category': 'Fruits', 'name': 'Banana'},
#   {'name': 'Spinach', 'category': 'Vegetables'},
#   {'category': 'Flowers', 'name': 'Rose'},
#   {'category': 'Flowers', 'name': 'Lotus'},
#   {'name': 'Dog', 'category': 'Animals'}]}
